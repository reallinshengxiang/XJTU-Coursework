# %%
# !pip install psycopg2
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import psycopg2
from psycopg2 import Error

def create_server_connection(host_name, port_name, user_name, user_password, dbname):
    connection = None
    try:
        connection = psycopg2.connect(
            host=host_name,
            port=port_name,
            user=user_name,
            password=user_password,
            database=dbname
        )
        print("openGauss Database connection successful")
    except Error as err:
        print(f"Error: '{err}'")
    
    return connection

connection = create_server_connection("localhost", "5432", "myuser", "123456abc.", "mydb")
# Out:
# openGauss Database connection successful

# %%
import psycopg2
from psycopg2 import Error

def create_server_connection(host_name, port_name, user_name, user_password, dbname):
    connection = None
    try:
        connection = psycopg2.connect(
            host=host_name,
            port=port_name,
            user=user_name,
            password=user_password,
            database=dbname
        )
        print("openGauss Database connection successful")
    except Error as err:
        print(f"Error: '{err}'")
    
    return connection

connection = create_server_connection("localhost", "5432", "linshengxiang", "lsx2004@38!", "db1")
# Out:
# openGauss Database connection successful

# %%
connection = create_server_connection("119.3.174.253", "8000", "linshengxiang", "lsx2004@38!", "db1")
# Out:
# Error: 'connection to server at "119.3.174.253", port 8000 failed: ERROR:  Invalid username/password,login denied.
# connection to server at "119.3.174.253", port 8000 failed: ERROR:  Invalid username/password,login denied.
# '

# %%
import psycopg2
from psycopg2 import Error

# 创建测试连接函数
def create_db_connection(host_name, port_name, user_name, user_password, dbname):
    connection = None
    try:
        connection = psycopg2.connect(
            dbname=dbname,
            user=user_name,
            password=user_password,
            host=host_name,
            port=port_name
        )
        print("openGauss Database connection successful")
    except Error as err:
        print(f"Error: '{err}'")

    return connection

# 使用示例
connection = create_db_connection("119.3.174.253", "8000", "root", "lsx2004@38!", "postgres")
# Out:
# Error: 'connection to server at "119.3.174.253", port 8000 failed: Connection timed out (0x0000274C/10060)
# 	Is the server running on that host and accepting TCP/IP connections?
# '

# %%
# !pip install psycopg2
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import psycopg2
from psycopg2 import Error

def create_server_connection(host_name, port_name, user_name, user_password, dbname):
    connection = None
    try:
        connection = psycopg2.connect(
            host=host_name,
            port=port_name,
            user=user_name,
            password=user_password,
            database=dbname
        )
        print("openGauss Database connection successful")
    except Error as err:
        print(f"Error: '{err}'")
    
    return connection

connection = create_server_connection("localhost", "5432", "myuser", "123456abc.", "mydb")
# Out:
# openGauss Database connection successful

# %%
if connection:
    try:
        cursor = connection.cursor()
        query = "SELECT * FROM myschema.Students;"
        cursor.execute(query)
        results = cursor.fetchall()
        column_names = [desc[0] for desc in cursor.description]
        print(" | ".join(column_names))
        print("-" * (sum(len(col) for col in column_names) + len(column_names) * 3 - 1))
        for row in results:
            print(" | ".join(str(value) for value in row))

    except Error as err:
        print(f"Error while executing query: '{err}'")
    finally:
        if cursor:
            cursor.close()
        if connection:
            connection.close()
            print("Database connection closed.")
# Out:
# stu_id | stu_name | stu_sex | stu_birthday
# --------------------------------------------
# Database connection closed.

# %%
def execute_query(connection, query):
    cursor = connection.cursor()
    try:
        cursor.execute(query)
        result = cursor.fetchall()
        return result
    except Error as err:
        print(f"Error: '{err}'")
    finally:
        cursor.close()
# 查询学生表信息
query = "SELECT * FROM myschema.students;"  # 假设学生表名为 "students"
students = execute_query(connection, query)

# 打印学生表信息
if students:
    for student in students:
        print(student)
else:
    print("No data found.")

# 关闭数据库连接
connection.close()
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# Cell In[16], line 13
#      11 # 查询学生表信息
#      12 query = "SELECT * FROM myschema.students;"  # 假设学生表名为 "students"
# ---> 13 students = execute_query(connection, query)
#      15 # 打印学生表信息
#      16 if students:
#
# Cell In[16], line 2, in execute_query(connection, query)
#       1 def execute_query(connection, query):
# ----> 2     cursor = connection.cursor()
#       3     try:
#       4         cursor.execute(query)
#
# InterfaceError: connection already closed
